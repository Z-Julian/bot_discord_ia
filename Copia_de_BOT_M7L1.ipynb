# %%
# !unzip ./modelo.zip
# Out:
# Archive:  ./modelo.zip
#  extracting: keras_model.h5
#  extracting: labels.txt

# %%
import PIL
PIL.__version__
# !pip install -q tf-keras==2.19.0 h5py==3.11.0
import tf_keras as keras  # Importando tf-keras – una versión de Keras compatible con modelos .h5
from tf_keras.models import load_model  # Importando la función load_model de tf_keras, que nos permite abrir el modelo
from PIL import Image, ImageOps  # Importar las clases Image e ImageOps de la biblioteca PIL
import numpy as np
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 91.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 86.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.20.1 requires tensorflow<2.21,>=2.20.0, but you have tensorflow 2.19.1 which is incompatible.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, but you have tensorflow 2.19.1 which is incompatible.

# %%
def get_class(model_path, labels_path, image_path):
  np.set_printoptions(suppress=True)
  model = load_model(model_path, compile=False)
  class_names = open(labels_path, "r").readlines()
  data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

  image = Image.open(image_path).convert("RGB")

  size = (224, 224)
  image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
  image_array = np.asarray(image)
  normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1
  data[0] = normalized_image_array
  prediction = model.predict(data)
  print(prediction)
  index = np.argmax(prediction)
  class_name = class_names[index]
  confidence_score = prediction[0][index]
  if confidence_score < 0.5:
    return "el modelo no puede dar una respuesta"
  else:
    return f"objeto detectado: {class_name[2:]} probabilidad: {confidence_score}"

# %%
# !pip install discord
# Out:
# Collecting discord
#   Downloading discord-2.3.2-py3-none-any.whl.metadata (381 bytes)
# Collecting discord.py>=2.3.2 (from discord)
#   Downloading discord_py-2.7.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from discord.py>=2.3.2->discord) (3.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.24.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (3.18)
# Downloading discord-2.3.2-py3-none-any.whl (1.1 kB)
# Downloading discord_py-2.7.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.8 MB/s eta 0:00:00
# Installing collected packages: discord.py, discord
# Successfully installed discord-2.3.2 discord.py-2.7.1

# %%
import discord
from discord.ext import commands
import nest_asyncio

nest_asyncio.apply()

# %%
nest_asyncio.apply()

intents = discord.Intents.default()
intents.message_content = True

bot = commands.Bot(command_prefix='$', intents=intents)

@bot.event
async def on_ready():
    print(f'We have logged in as {bot.user}')

@bot.command()
async def check(ctx):
    if ctx.message.attachments:
      for attachment in ctx.message.attachments:
        file_name = attachment.filename
        file_url = attachment.url
        await attachment.save(f"./{file_name}")
        await ctx.send("Imagen guardad con exito")
        await ctx.send(get_class(model_path="./keras_model.h5", labels_path="labels.txt", image_path=f"./{foto.filename}"))
    else:
      await ctx.send("olvidaste subir una imagen")


@bot.command()
async def heh(ctx, count_heh = 5):
    await ctx.send("he" * count_heh)

bot.run("MTUwNjgxODQ0MTUxNDg0ODQyOQ.GgTpPr.sOFNilxEWAYGcB-i36J1E1KHcZelPd7hOb0oWs")
# Out:
# WARNING:discord.client:PyNaCl is not installed, voice will NOT be supported
# WARNING:discord.client:davey is not installed, voice will NOT be supported
# 2026-06-06 18:03:45 INFO     discord.client logging in using static token
# INFO:discord.client:logging in using static token
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/discord/http.py in static_login(self, token)
#     843         try:
# --> 844             data = await self.request(Route('GET', '/users/@me'))
#     845         except HTTPException as exc:
#
# /usr/local/lib/python3.12/dist-packages/discord/http.py in request(self, route, files, form, **kwargs)
#     777                         else:
# --> 778                             raise HTTPException(response, data)
#     779
#
# HTTPException: 401 Unauthorized (error code: 0): 401: Unauthorized
#
# The above exception was the direct cause of the following exception:
#
# LoginFailure                              Traceback (most recent call last)
# /tmp/ipykernel_2745/587580741.py in <cell line: 0>()
#      27     await ctx.send("he" * count_heh)
#      28
# ---> 29 bot.run("MTUwNjgxODQ0MTUxNDg0ODQyOQ.GgTpPr.sOFNilxEWAYGcB-i36J1E1KHcZelPd7hOb0oWs")
#
# /usr/local/lib/python3.12/dist-packages/discord/client.py in run(self, token, reconnect, log_handler, log_formatter, log_level, root_logger)
#     931
#     932         try:
# --> 933             asyncio.run(runner())
#     934         except KeyboardInterrupt:
#     935             # nothing to do here
#
# /usr/local/lib/python3.12/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.12/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      96                 raise RuntimeError(
#      97                     'Event loop stopped before Future completed.')
# ---> 98             return f.result()
#      99
#     100     def _run_once(self):
#
# /usr/lib/python3.12/asyncio/futures.py in result(self)
#     200         self.__log_traceback = False
#     201         if self._exception is not None:
# --> 202             raise self._exception.with_traceback(self._exception_tb)
#     203         return self._result
#     204
#
# /usr/lib/python3.12/asyncio/tasks.py in __step_run_and_handle_result(***failed resolving arguments***)
#     312                 # We use the `send` method directly, because coroutines
#     313                 # don't have `__iter__` and `__next__` methods.
# --> 314                 result = coro.send(None)
#     315             else:
#     316                 result = coro.throw(exc)
#
# /usr/local/lib/python3.12/dist-packages/discord/client.py in runner()
#     920         async def runner():
#     921             async with self:
# --> 922                 await self.start(token, reconnect=reconnect)
#     923
#     924         if log_handler is not None:
#
# /usr/local/lib/python3.12/dist-packages/discord/client.py in start(self, token, reconnect)
#     848             An unexpected keyword argument was received.
#     849         """
# --> 850         await self.login(token)
#     851         await self.connect(reconnect=reconnect)
#     852
#
# /usr/local/lib/python3.12/dist-packages/discord/client.py in login(self, token)
#     677         token = token.strip()
#     678
# --> 679         data = await self.http.static_login(token)
#     680         self._connection.user = ClientUser(state=self._connection, data=data)
#     681         self._application = await self.application_info()
#
# /usr/local/lib/python3.12/dist-packages/discord/http.py in static_login(self, token)
#     846             self.token = old_token
#     847             if exc.status == 401:
# --> 848                 raise LoginFailure('Improper token has been passed.') from exc
#     849             raise
#     850
#
# LoginFailure: Improper token has been passed.
